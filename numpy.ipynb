# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenadhrajesh/javaproject/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ml lab")
# Out:
# ml lab

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
import numpy as np
a=np.array([[1,2,3,4],[5,6,7,8]])
print(a)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
import numpy as np
a=np.array([[1,2,3,4],[5,6,7,8]])
print(a.shape)
# Out:
# (2, 4)

# %%
import numpy as np
a=np.array([[1,2,3,4],[5,6,7,8]])
print(a.ndim)
# Out:
# 2

# %%
import numpy as np
a=np.zeros(5)
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
import numpy as np
a=np.ones(5)
print(a)
# Out:
# [1. 1. 1. 1. 1.]

# %%
import numpy as np
a=np.arange(1,10,2)
print(a)
# Out:
# [1 3 5 7 9]

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a+5)
# Out:
# [6 7 8 9]

# %%
import numpy as np
a=np.array([[1,2,3,4],[5,6,7,8]])
print(np.sum(a))
# Out:
# 36

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a*2)
# Out:
# [2 4 6 8]

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.sum(a))
# Out:
# 10

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.mean(a))
# Out:
# 2.5

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.max(a))
# Out:
# 4

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.min(a))
# Out:
# 1

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.std(a))
# Out:
# 1.118033988749895

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a[0])
print(a[1])
# Out:
# 1
# 2

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a[1:4])
# Out:
# [2 3 4]

# %%
import matplotlib.pyplot as plt
plt.title("Daily Sales")
plt.xlabel("Days")
plt.ylabel("Sales")
days=[1,2,3,4,5]
sales=[100,120,140,130,160]
plt.plot(days,sales)
plt.show()

# %%
import matplotlib.pyplot as plt
subjects=["maths","physics","chemistry"]
marks=[80,92,75]
plt.bar(subjects,marks)
plt.title("Marks in subjects")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
subjects=["maths","physics","chemistry"]
marks=[80,92,75]
plt.barh(subjects, marks)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
subjects=["maths","physics","chemistry"]
marks=[80,92,75]
plt.pie(marks,labels=subjects,autopct='%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
hours=[1,2,3,4,5]
marks=[80,92,75,60,50]
plt.scatter(hours,marks)
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
marks=[45,50,60,70,72,75,80,82,90,95]
plt.hist(marks)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y1=[5,6,7,8]
y2=[2,4,6,8]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
